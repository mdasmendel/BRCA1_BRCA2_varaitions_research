# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B196_Seq137.bam"
targeted_vcf = f"{data_root}/B196_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B196_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B196_Seq137.bam -O ../../data/B196_Seq137.vcf -L ../../data/location.bed
# 23:09:57.636 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 23:09:57.873 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:09:57.877 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 23:09:57.877 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 23:09:57.877 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 23:09:57.877 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 23:09:57.877 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 11:09:57 PM EEST
# 23:09:57.877 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:09:57.877 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:09:57.881 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 23:09:57.881 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 23:09:57.882 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 23:09:57.882 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 23:09:57.883 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 23:09:57.883 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 23:09:57.884 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 23:09:57.884 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 23:09:57.884 INFO  HaplotypeCaller - Inflater: IntelInflater
# 23:09:57.884 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 23:09:57.885 INFO  HaplotypeCaller - Requester pays: disabled
# 23:09:57.885 INFO  HaplotypeCaller - Initializing engine
# 23:09:58.229 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 23:09:58.237 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 23:09:58.245 INFO  HaplotypeCaller - Done initializing engine
# 23:09:58.277 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 23:09:58.292 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 23:09:58.360 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 23:09:58.360 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 23:09:58.361 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 23:09:58.481 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 23:09:58.482 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 23:09:58.482 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 23:09:58.514 INFO  ProgressMeter - Starting traversal
# 23:09:58.515 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 23:09:59.851 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32890627 and possibly subsequent; at least 10 samples must have called genotypes
# 23:10:12.444 INFO  ProgressMeter -       chr13:32900405              0.2                    40            172.3
# 23:10:33.701 INFO  ProgressMeter -       chr13:32907255              0.6                    70            119.4
# 23:11:16.371 INFO  ProgressMeter -       chr13:32911883              1.3                    90             69.4
# 23:11:31.514 INFO  ProgressMeter -       chr13:32912901              1.5                   100             64.5
# 23:12:13.158 INFO  ProgressMeter -       chr13:32914473              2.2                   110             49.0
# 23:12:30.074 INFO  ProgressMeter -       chr13:32916947              2.5                   120             47.5
# 23:12:46.240 INFO  ProgressMeter -       chr13:32930613              2.8                   170             60.8
# 23:13:05.295 INFO  ProgressMeter -       chr13:32937821              3.1                   200             64.2
# 23:13:17.694 INFO  ProgressMeter -       chr13:32955601              3.3                   270             81.3
# 23:14:02.709 INFO  ProgressMeter -       chr17:41197065              4.1                   340             83.5
# 23:14:13.544 INFO  ProgressMeter -       chr17:41225157              4.3                   460            108.2
# 23:14:50.422 INFO  ProgressMeter -       chr17:41245298              4.9                   540            111.0
# 23:15:15.442 INFO  ProgressMeter -       chr17:41247752              5.3                   550            104.1
# 23:15:19.480 INFO  HaplotypeCaller - 2145 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 2145 total reads filtered out of 55032 reads processed
# 23:15:19.480 INFO  ProgressMeter -       chr17:41277497              5.3                   660            123.4
# 23:15:19.480 INFO  ProgressMeter - Traversal complete. Processed 660 total regions in 5.3 minutes.
# 23:15:19.508 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.058738378
# 23:15:19.509 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 282.18311806
# 23:15:19.509 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 26.58 sec
# 23:15:19.510 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:15:19 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 5.37 minutes.
# Runtime.totalMemory()=587202560
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT   QUAL FILTER  \
# 0  chr13  32890627  .   A  AT  298.6      .
# 1  chr13  32893180  .  GT   G  561.6      .
# 2  chr13  32900363  .  CT   C  317.6      .
# 3  chr13  32900440  .  AT   A  217.6      .
# 4  chr13  32900488  .  GC   G   52.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.294;DP=79;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.603;DP=79;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.714;DP=83;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.748;DP=99;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-4.253;DP=99;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:61,18:79:99:306,0,1621
# 1  0/1:56,23:79:99:569,0,1800
# 2  0/1:62,20:82:99:325,0,1612
# 3  0/1:83,16:99:99:225,0,2394
# 4   0/1:88,10:98:60:60,0,2846
