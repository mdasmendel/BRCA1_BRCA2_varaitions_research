# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B175_Seq136.bam"
targeted_vcf = f"{data_root}/B175_Seq136.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B175_Seq136.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B175_Seq136.bam -O ../../data/B175_Seq136.vcf -L ../../data/location.bed
# 22:26:53.807 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 22:26:54.054 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:26:54.059 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 22:26:54.059 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 22:26:54.059 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 22:26:54.059 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 22:26:54.059 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 10:26:53 PM EEST
# 22:26:54.059 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:26:54.060 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:26:54.060 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 22:26:54.061 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 22:26:54.061 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 22:26:54.061 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 22:26:54.061 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 22:26:54.061 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 22:26:54.062 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 22:26:54.062 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 22:26:54.062 INFO  HaplotypeCaller - Inflater: IntelInflater
# 22:26:54.062 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 22:26:54.062 INFO  HaplotypeCaller - Requester pays: disabled
# 22:26:54.063 INFO  HaplotypeCaller - Initializing engine
# 22:26:54.451 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 22:26:54.463 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 22:26:54.474 INFO  HaplotypeCaller - Done initializing engine
# 22:26:54.495 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 22:26:54.511 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 22:26:54.746 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 22:26:54.747 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 22:26:54.747 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 22:26:54.953 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 22:26:54.954 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 22:26:54.954 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 22:26:54.995 INFO  ProgressMeter - Starting traversal
# 22:26:54.996 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 22:26:56.729 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 22:27:07.611 INFO  ProgressMeter -       chr13:32900679              0.2                    40            190.3
# 22:27:42.362 INFO  ProgressMeter -       chr13:32907255              0.8                    70             88.7
# 22:28:47.404 INFO  ProgressMeter -       chr13:32911599              1.9                    90             48.0
# 22:29:38.902 INFO  ProgressMeter -       chr13:32913193              2.7                   100             36.6
# 22:30:48.453 INFO  ProgressMeter -       chr13:32915127              3.9                   110             28.3
# 22:31:11.810 INFO  ProgressMeter -       chr13:32930830              4.3                   170             39.7
# 22:31:35.965 INFO  ProgressMeter -       chr13:32938121              4.7                   200             42.7
# 22:31:55.980 INFO  ProgressMeter -       chr13:32955901              5.0                   270             53.8
# 22:32:12.395 INFO  ProgressMeter -       chr13:32970381              5.3                   320             60.5
# 22:33:09.117 INFO  ProgressMeter -       chr17:41196313              6.2                   330             52.9
# 22:33:20.329 INFO  ProgressMeter -       chr17:41209552              6.4                   390             60.7
# 22:33:31.718 INFO  ProgressMeter -       chr17:41224857              6.6                   450             68.1
# 22:33:56.403 INFO  ProgressMeter -       chr17:41244673              7.0                   530             75.5
# 22:34:49.704 INFO  ProgressMeter -       chr17:41246465              7.9                   540             68.3
# 22:34:59.444 INFO  HaplotypeCaller - 1577 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1577 total reads filtered out of 31633 reads processed
# 22:34:59.444 INFO  ProgressMeter -       chr17:41276012              8.1                   656             81.2
# 22:34:59.444 INFO  ProgressMeter - Traversal complete. Processed 656 total regions in 8.1 minutes.
# 22:34:59.486 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.083753776
# 22:34:59.486 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 425.23653508700005
# 22:34:59.486 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 39.77 sec
# 22:34:59.487 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 10:34:59 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 8.10 minutes.
# Runtime.totalMemory()=595591168
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .  GT   G  875.6      .
# 1  chr13  32900355  .  AT   A  184.6      .
# 2  chr13  32900363  .  CT   C  533.6      .
# 3  chr13  32903565  .  AT   A  110.6      .
# 4  chr13  32903635  .  TA   T  132.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=1.053;DP=52;Ex...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.272;DP=80;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.156;DP=82;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.061;DP=26;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.798;DP=30;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0   0/1:22,30:52:99:883,0,648
# 1  0/1:63,17:80:99:192,0,1802
# 2  0/1:51,29:80:99:541,0,1227
# 3    0/1:20,6:26:99:118,0,549
# 4    0/1:22,8:30:99:140,0,694
