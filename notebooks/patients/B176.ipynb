# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B176_Seq136.bam"
targeted_vcf = f"{data_root}/B176_Seq136.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B176_Seq136.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B176_Seq136.bam -O ../../data/B176_Seq136.vcf -L ../../data/location.bed
# 22:27:40.656 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 22:27:40.870 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:40.876 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 22:27:40.876 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 22:27:40.877 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 22:27:40.877 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 22:27:40.877 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 10:27:40 PM EEST
# 22:27:40.877 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:40.877 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:40.879 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 22:27:40.879 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 22:27:40.879 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 22:27:40.880 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 22:27:40.880 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 22:27:40.880 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 22:27:40.881 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 22:27:40.881 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 22:27:40.881 INFO  HaplotypeCaller - Inflater: IntelInflater
# 22:27:40.882 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 22:27:40.882 INFO  HaplotypeCaller - Requester pays: disabled
# 22:27:40.883 INFO  HaplotypeCaller - Initializing engine
# 22:27:41.400 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 22:27:41.412 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 22:27:41.423 INFO  HaplotypeCaller - Done initializing engine
# 22:27:41.460 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 22:27:41.482 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 22:27:41.558 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 22:27:41.559 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 22:27:41.559 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 22:27:41.769 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 22:27:41.770 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 22:27:41.770 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 22:27:41.860 INFO  ProgressMeter - Starting traversal
# 22:27:41.861 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 22:27:44.857 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 22:27:55.697 INFO  ProgressMeter -       chr13:32901441              0.2                    50            216.8
# 22:28:31.891 INFO  ProgressMeter -       chr13:32908318              0.8                    80             95.9
# 22:29:02.901 INFO  ProgressMeter -       chr13:32910909              1.4                    90             66.6
# 22:30:03.430 INFO  ProgressMeter -       chr13:32912905              2.4                   100             42.4
# 22:30:45.673 INFO  ProgressMeter -       chr13:32914704              3.1                   110             35.9
# 22:30:55.742 INFO  ProgressMeter -       chr13:32920079              3.2                   130             40.2
# 22:31:13.112 INFO  ProgressMeter -       chr13:32930614              3.5                   170             48.3
# 22:31:28.293 INFO  ProgressMeter -       chr13:32937514              3.8                   200             53.0
# 22:31:44.352 INFO  ProgressMeter -       chr13:32955301              4.0                   270             66.8
# 22:32:39.028 INFO  ProgressMeter -       chr17:41197069              5.0                   340             68.6
# 22:32:49.116 INFO  ProgressMeter -       chr17:41199128              5.1                   350             68.3
# 22:32:59.601 INFO  ProgressMeter -       chr17:41243351              5.3                   530            100.1
# 22:33:45.009 INFO  ProgressMeter -       chr17:41245300              6.1                   540             89.2
# 22:34:13.909 INFO  ProgressMeter -       chr17:41247296              6.5                   550             84.2
# 22:34:14.494 INFO  HaplotypeCaller - 1183 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1183 total reads filtered out of 23164 reads processed
# 22:34:14.495 INFO  ProgressMeter -       chr17:41277497              6.5                   660            100.9
# 22:34:14.495 INFO  ProgressMeter - Traversal complete. Processed 660 total regions in 6.5 minutes.
# 22:34:14.539 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.10874473300000001
# 22:34:14.539 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 338.411367782
# 22:34:14.539 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 36.25 sec
# 22:34:14.540 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 10:34:14 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 6.57 minutes.
# Runtime.totalMemory()=541065216
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID  REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .   GT   G  324.6      .
# 1  chr13  32893322  .   CA   C   45.6      .
# 2  chr13  32900363  .   CT   C  737.6      .
# 3  chr13  32903565  .   AT   A  190.6      .
# 4  chr13  32903635  .  TAA   T  459.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.704;DP=45;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.714;DP=41;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.572;DP=86;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.246;DP=21;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-4.062;DP=25;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:32,13:45:99:332,0,1025
# 1    0/1:36,5:41:53:53,0,1148
# 2  0/1:48,34:82:99:745,0,1153
# 3    0/1:13,8:21:99:198,0,355
# 4   0/1:12,12:24:99:467,0,468
