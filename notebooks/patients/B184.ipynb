# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B184_Seq137.bam"
targeted_vcf = f"{data_root}/B184_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B184_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B184_Seq137.bam -O ../../data/B184_Seq137.vcf -L ../../data/location.bed
# 22:57:02.760 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 22:57:02.972 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:57:02.978 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 22:57:02.978 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 22:57:02.978 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 22:57:02.978 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 22:57:02.979 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 10:57:02 PM EEST
# 22:57:02.979 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:57:02.979 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:57:02.981 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 22:57:02.982 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 22:57:02.982 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 22:57:02.982 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 22:57:02.983 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 22:57:02.983 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 22:57:02.983 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 22:57:02.984 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 22:57:02.984 INFO  HaplotypeCaller - Inflater: IntelInflater
# 22:57:02.984 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 22:57:02.984 INFO  HaplotypeCaller - Requester pays: disabled
# 22:57:02.985 INFO  HaplotypeCaller - Initializing engine
# 22:57:03.484 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 22:57:03.499 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 22:57:03.511 INFO  HaplotypeCaller - Done initializing engine
# 22:57:03.555 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 22:57:03.574 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 22:57:03.651 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 22:57:03.651 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 22:57:03.652 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 22:57:03.873 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 22:57:03.874 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 22:57:03.874 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 22:57:03.928 INFO  ProgressMeter - Starting traversal
# 22:57:03.928 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 22:57:05.004 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 22:57:18.809 INFO  ProgressMeter -       chr13:32902065              0.2                    50            201.6
# 22:57:31.634 INFO  ProgressMeter -       chr13:32906508              0.5                    70            151.6
# 22:57:51.517 INFO  ProgressMeter -       chr13:32908618              0.8                    80            100.9
# 22:58:21.984 INFO  ProgressMeter -       chr13:32910897              1.3                    90             69.2
# 22:59:15.340 INFO  ProgressMeter -       chr13:32912889              2.2                   100             45.7
# 23:00:01.685 INFO  ProgressMeter -       chr13:32914198              3.0                   110             37.1
# 23:00:28.193 INFO  ProgressMeter -       chr13:32916647              3.4                   120             35.2
# 23:00:43.140 INFO  ProgressMeter -       chr13:32930472              3.7                   170             46.5
# 23:01:03.322 INFO  ProgressMeter -       chr13:32937657              4.0                   200             50.1
# 23:01:14.530 INFO  ProgressMeter -       chr13:32955601              4.2                   270             64.6
# 23:01:52.590 INFO  ProgressMeter -       chr17:41196321              4.8                   340             70.7
# 23:02:02.761 INFO  ProgressMeter -       chr17:41198228              5.0                   350             70.3
# 23:02:13.847 INFO  ProgressMeter -       chr17:41227687              5.2                   480             92.9
# 23:02:36.476 INFO  ProgressMeter -       chr17:41244757              5.5                   550             99.2
# 23:03:18.863 INFO  ProgressMeter -       chr17:41246744              6.2                   560             89.6
# 23:03:20.993 INFO  HaplotypeCaller - 1427 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1427 total reads filtered out of 32970 reads processed
# 23:03:20.993 INFO  ProgressMeter -       chr17:41276603              6.3                   672            106.9
# 23:03:20.993 INFO  ProgressMeter - Traversal complete. Processed 672 total regions in 6.3 minutes.
# 23:03:21.033 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.06582075800000001
# 23:03:21.033 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 328.104528539
# 23:03:21.033 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 33.38 sec
# 23:03:21.034 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:03:21 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 6.31 minutes.
# Runtime.totalMemory()=599785472
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .  GT   G  603.6      .
# 1  chr13  32900363  .  CT   C  323.6      .
# 2  chr13  32900440  .  AT   A   98.6      .
# 3  chr13  32903565  .  AT   A   55.6      .
# 4  chr13  32903635  .  TA   T  421.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.872;DP=61;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.007;DP=75;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.399;DP=84;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.395;DP=55;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-4.862;DP=60;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:38,22:60:99:611,0,1177
# 1  0/1:56,19:75:99:331,0,1438
# 2  0/1:73,11:84:99:106,0,2110
# 3    0/1:48,7:55:63:63,0,1308
# 4  0/1:36,24:60:99:429,0,1107
