# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/R127_Seq137.bam"
targeted_vcf = f"{data_root}/R127_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/R127_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/R127_Seq137.bam -O ../../data/R127_Seq137.vcf -L ../../data/location.bed
# 23:19:31.359 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 23:19:31.538 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:31.542 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 23:19:31.542 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 23:19:31.542 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 23:19:31.542 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 23:19:31.542 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 11:19:31 PM EEST
# 23:19:31.543 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:31.543 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:31.544 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 23:19:31.544 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 23:19:31.544 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 23:19:31.544 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 23:19:31.544 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 23:19:31.544 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 23:19:31.545 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 23:19:31.545 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 23:19:31.545 INFO  HaplotypeCaller - Inflater: IntelInflater
# 23:19:31.545 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 23:19:31.545 INFO  HaplotypeCaller - Requester pays: disabled
# 23:19:31.546 INFO  HaplotypeCaller - Initializing engine
# 23:19:31.933 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 23:19:31.944 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 23:19:31.957 INFO  HaplotypeCaller - Done initializing engine
# 23:19:31.967 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 23:19:31.984 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 23:19:32.054 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 23:19:32.055 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 23:19:32.055 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 23:19:32.206 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 23:19:32.207 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 23:19:32.207 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 23:19:32.271 INFO  ProgressMeter - Starting traversal
# 23:19:32.272 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 23:19:34.225 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 23:19:54.107 INFO  ProgressMeter -       chr13:32900679              0.4                    40            109.9
# 23:20:35.150 INFO  ProgressMeter -       chr13:32907307              1.0                    70             66.8
# 23:21:38.298 INFO  ProgressMeter -       chr13:32911972              2.1                    90             42.8
# 23:22:07.158 INFO  ProgressMeter -       chr13:32912902              2.6                   100             38.7
# 23:23:05.812 INFO  ProgressMeter -       chr13:32914532              3.6                   110             30.9
# 23:23:16.358 INFO  ProgressMeter -       chr13:32920079              3.7                   130             34.8
# 23:23:34.295 INFO  ProgressMeter -       chr13:32930830              4.0                   170             42.1
# 23:24:00.758 INFO  ProgressMeter -       chr13:32937821              4.5                   200             44.7
# 23:24:18.304 INFO  ProgressMeter -       chr13:32953479              4.8                   260             54.5
# 23:24:35.942 INFO  ProgressMeter -       chr13:32969781              5.1                   320             63.2
# 23:25:14.529 INFO  ProgressMeter -       chr17:41197067              5.7                   340             59.6
# 23:25:27.644 INFO  ProgressMeter -       chr17:41224557              5.9                   460             77.7
# 23:25:53.108 INFO  ProgressMeter -       chr17:41243876              6.3                   540             85.1
# 23:26:35.704 INFO  ProgressMeter -       chr17:41245640              7.1                   550             77.9
# 23:26:54.707 INFO  ProgressMeter -       chr17:41247910              7.4                   560             75.9
# 23:26:58.733 INFO  HaplotypeCaller - 2271 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 2271 total reads filtered out of 53518 reads processed
# 23:26:58.733 INFO  ProgressMeter -       chr17:41275937              7.4                   667             89.6
# 23:26:58.733 INFO  ProgressMeter - Traversal complete. Processed 667 total regions in 7.4 minutes.
# 23:26:58.761 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.07856023100000001
# 23:26:58.761 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 396.58443389900003
# 23:26:58.762 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 33.83 sec
# 23:26:58.762 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:26:58 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 7.46 minutes.
# Runtime.totalMemory()=528482304
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT     QUAL FILTER  \
# 0  chr13  32893180  .  GT   G   300.60      .
# 1  chr13  32899388  .   A   C  1508.64      .
# 2  chr13  32900363  .  CT   C   543.60      .
# 3  chr13  32900440  .  AT   A   110.60      .
# 4  chr13  32903635  .  TA   T   679.60      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.205;DP=84;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=3.843;DP=98;Ex...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.245;DP=86;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.496;DP=91;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-5.315;DP=101;...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:67,17:84:99:308,0,2153
# 1  0/1:42,56:98:99:1516,0,814
# 2  0/1:58,27:85:99:551,0,1526
# 3  0/1:79,12:91:99:118,0,2283
# 4  0/1:54,28:82:99:687,0,1706
