# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B179_Seq136.bam"
targeted_vcf = f"{data_root}/B179_Seq136.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B179_Seq136.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B179_Seq136.bam -O ../../data/B179_Seq136.vcf -L ../../data/location.bed
# 22:27:48.358 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 22:27:48.611 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:48.620 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 22:27:48.620 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 22:27:48.620 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 22:27:48.620 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 22:27:48.621 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 10:27:48 PM EEST
# 22:27:48.621 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:48.621 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:48.623 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 22:27:48.623 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 22:27:48.623 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 22:27:48.623 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 22:27:48.624 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 22:27:48.624 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 22:27:48.624 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 22:27:48.624 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 22:27:48.624 INFO  HaplotypeCaller - Inflater: IntelInflater
# 22:27:48.625 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 22:27:48.625 INFO  HaplotypeCaller - Requester pays: disabled
# 22:27:48.625 INFO  HaplotypeCaller - Initializing engine
# 22:27:49.137 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 22:27:49.145 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 22:27:49.154 INFO  HaplotypeCaller - Done initializing engine
# 22:27:49.175 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 22:27:49.198 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 22:27:49.276 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 22:27:49.276 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 22:27:49.277 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 22:27:49.485 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 22:27:49.485 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 22:27:49.486 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 22:27:49.534 INFO  ProgressMeter - Starting traversal
# 22:27:49.535 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 22:27:51.858 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 22:28:00.919 INFO  ProgressMeter -       chr13:32900234              0.2                    40            210.8
# 22:28:27.336 INFO  ProgressMeter -       chr13:32906772              0.6                    70            111.1
# 22:28:37.686 INFO  ProgressMeter -       chr13:32909218              0.8                    80             99.7
# 22:29:15.039 INFO  ProgressMeter -       chr13:32911405              1.4                    90             63.2
# 22:29:49.546 INFO  ProgressMeter -       chr13:32912890              2.0                   100             50.0
# 22:30:40.728 INFO  ProgressMeter -       chr13:32914196              2.9                   110             38.6
# 22:31:10.395 INFO  ProgressMeter -       chr13:32916647              3.3                   120             35.8
# 22:31:27.362 INFO  ProgressMeter -       chr13:32930146              3.6                   170             46.8
# 22:31:45.990 INFO  ProgressMeter -       chr13:32937320              3.9                   200             50.7
# 22:32:03.375 INFO  ProgressMeter -       chr13:32944987              4.2                   230             54.4
# 22:32:32.272 INFO  ProgressMeter -       chr13:32954401              4.7                   270             57.3
# 22:32:43.538 INFO  ProgressMeter -       chr13:32969085              4.9                   320             65.3
# 22:33:03.533 INFO  ProgressMeter -       chr17:41196313              5.2                   340             65.0
# 22:33:18.949 INFO  ProgressMeter -       chr17:41197928              5.5                   350             63.7
# 22:33:29.036 INFO  ProgressMeter -       chr17:41223657              5.7                   460             81.3
# 22:33:50.276 INFO  ProgressMeter -       chr17:41244167              6.0                   540             89.8
# 22:34:25.598 INFO  ProgressMeter -       chr17:41246103              6.6                   550             83.3
# 22:34:51.390 INFO  ProgressMeter -       chr17:41247911              7.0                   560             79.6
# 22:34:53.734 INFO  HaplotypeCaller - 1404 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1404 total reads filtered out of 30609 reads processed
# 22:34:53.734 INFO  ProgressMeter -       chr17:41275431              7.1                   668             94.5
# 22:34:53.734 INFO  ProgressMeter - Traversal complete. Processed 668 total regions in 7.1 minutes.
# 22:34:53.772 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.082510439
# 22:34:53.773 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 369.03807330800004
# 22:34:53.773 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 37.74 sec
# 22:34:53.774 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 10:34:53 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 7.09 minutes.
# Runtime.totalMemory()=486539264
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID  REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .   GT   G  656.6      .
# 1  chr13  32900363  .   CT   C  545.6      .
# 2  chr13  32903565  .   AT   A   78.6      .
# 3  chr13  32903635  .  TAA   T  118.6      .
# 4  chr13  32905046  .   AT   A  658.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.633;DP=66;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.676;DP=79;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=0.988;DP=15;Ex...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.044;DP=19;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.865;DP=75;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:42,24:66:99:664,0,1340
# 1  0/1:51,27:78:99:553,0,1313
# 2     0/1:11,4:15:86:86,0,272
# 3    0/1:14,4:18:99:126,0,576
# 4  0/1:37,27:64:99:666,0,1000
