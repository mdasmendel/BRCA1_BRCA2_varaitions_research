# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/R122_Seq137.bam"
targeted_vcf = f"{data_root}/R122_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/R122_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/R122_Seq137.bam -O ../../data/R122_Seq137.vcf -L ../../data/location.bed
# 23:19:22.001 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 23:19:22.293 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:22.297 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 23:19:22.297 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 23:19:22.297 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 23:19:22.297 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 23:19:22.298 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 11:19:21 PM EEST
# 23:19:22.298 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:22.298 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:22.299 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 23:19:22.299 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 23:19:22.299 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 23:19:22.300 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 23:19:22.300 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 23:19:22.300 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 23:19:22.300 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 23:19:22.300 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 23:19:22.301 INFO  HaplotypeCaller - Inflater: IntelInflater
# 23:19:22.301 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 23:19:22.301 INFO  HaplotypeCaller - Requester pays: disabled
# 23:19:22.302 INFO  HaplotypeCaller - Initializing engine
# 23:19:22.703 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 23:19:22.730 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 23:19:22.741 INFO  HaplotypeCaller - Done initializing engine
# 23:19:22.802 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 23:19:22.818 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 23:19:22.901 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 23:19:22.902 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 23:19:22.902 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 23:19:23.179 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 23:19:23.180 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 23:19:23.180 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 23:19:23.223 INFO  ProgressMeter - Starting traversal
# 23:19:23.224 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 23:19:27.589 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 23:19:35.193 INFO  ProgressMeter -       chr13:32895354              0.2                    20            100.3
# 23:19:49.877 INFO  ProgressMeter -       chr13:32900233              0.4                    40             90.1
# 23:20:01.119 INFO  ProgressMeter -       chr13:32904955              0.6                    60             95.0
# 23:20:26.918 INFO  ProgressMeter -       chr13:32906812              1.1                    70             65.9
# 23:20:44.139 INFO  ProgressMeter -       chr13:32909218              1.3                    80             59.3
# 23:21:25.378 INFO  ProgressMeter -       chr13:32911500              2.0                    90             44.2
# 23:22:09.877 INFO  ProgressMeter -       chr13:32912890              2.8                   100             36.0
# 23:22:55.387 INFO  ProgressMeter -       chr13:32914371              3.5                   110             31.1
# 23:23:15.901 INFO  ProgressMeter -       chr13:32916347              3.9                   120             30.9
# 23:23:29.187 INFO  ProgressMeter -       chr13:32929846              4.1                   170             41.5
# 23:23:43.137 INFO  ProgressMeter -       chr13:32936717              4.3                   200             46.2
# 23:24:00.467 INFO  ProgressMeter -       chr13:32939321              4.6                   210             45.4
# 23:24:20.519 INFO  ProgressMeter -       chr13:32953959              5.0                   270             54.5
# 23:24:30.649 INFO  ProgressMeter -       chr13:32970937              5.1                   330             64.4
# 23:24:48.920 INFO  ProgressMeter -       chr13:32972472              5.4                   340             62.6
# 23:25:11.195 INFO  ProgressMeter -       chr17:41197813              5.8                   350             60.4
# 23:25:22.230 INFO  ProgressMeter -       chr17:41223131              6.0                   460             76.9
# 23:25:32.477 INFO  ProgressMeter -       chr17:41228485              6.2                   480             78.0
# 23:25:49.616 INFO  ProgressMeter -       chr17:41244167              6.4                   540             83.9
# 23:26:25.923 INFO  ProgressMeter -       chr17:41245927              7.0                   550             78.1
# 23:26:46.785 INFO  ProgressMeter -       chr17:41247908              7.4                   560             75.8
# 23:26:48.823 INFO  HaplotypeCaller - 2187 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 2187 total reads filtered out of 51443 reads processed
# 23:26:48.824 INFO  ProgressMeter -       chr17:41275731              7.4                   668             89.9
# 23:26:48.824 INFO  ProgressMeter - Traversal complete. Processed 668 total regions in 7.4 minutes.
# 23:26:48.862 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.094695027
# 23:26:48.863 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 392.81322431700005
# 23:26:48.863 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 35.54 sec
# 23:26:48.863 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:26:48 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 7.45 minutes.
# Runtime.totalMemory()=587202560
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT    QUAL FILTER  \
# 0  chr13  32893180  .  GT   G   502.6      .
# 1  chr13  32900363  .  CT   C   210.6      .
# 2  chr13  32903565  .  AT   A   108.6      .
# 3  chr13  32903635  .  TA   T  1131.6      .
# 4  chr13  32905046  .  AT   A   894.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.623;DP=87;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.789;DP=97;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.511;DP=70;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-5.111;DP=76;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.457;DP=87;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:66,21:87:99:510,0,2148
# 1  0/1:74,20:94:99:218,0,1925
# 2  0/1:60,10:70:99:116,0,1690
# 3  0/1:30,46:76:99:1139,0,846
# 4  0/1:45,35:80:99:902,0,1212
