# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B177_Seq136.bam"
targeted_vcf = f"{data_root}/B177_Seq136.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B177_Seq136.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B177_Seq136.bam -O ../../data/B177_Seq136.vcf -L ../../data/location.bed
# 22:27:44.453 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 22:27:44.701 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:44.707 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 22:27:44.707 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 22:27:44.707 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 22:27:44.707 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 22:27:44.708 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 10:27:44 PM EEST
# 22:27:44.708 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:44.708 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:44.709 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 22:27:44.709 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 22:27:44.710 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 22:27:44.710 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 22:27:44.710 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 22:27:44.711 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 22:27:44.711 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 22:27:44.711 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 22:27:44.711 INFO  HaplotypeCaller - Inflater: IntelInflater
# 22:27:44.712 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 22:27:44.712 INFO  HaplotypeCaller - Requester pays: disabled
# 22:27:44.712 INFO  HaplotypeCaller - Initializing engine
# 22:27:45.208 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 22:27:45.219 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 22:27:45.235 INFO  HaplotypeCaller - Done initializing engine
# 22:27:45.297 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 22:27:45.318 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 22:27:45.393 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 22:27:45.394 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 22:27:45.395 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 22:27:45.606 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 22:27:45.607 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 22:27:45.607 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 22:27:45.659 INFO  ProgressMeter - Starting traversal
# 22:27:45.660 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 22:27:46.672 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 22:28:06.555 INFO  ProgressMeter -       chr13:32906808              0.3                    70            201.0
# 22:28:39.045 INFO  ProgressMeter -       chr13:32911410              0.9                    90            101.2
# 22:29:18.212 INFO  ProgressMeter -       chr13:32912889              1.5                   100             64.8
# 22:29:56.016 INFO  ProgressMeter -       chr13:32914197              2.2                   110             50.6
# 22:30:25.543 INFO  ProgressMeter -       chr13:32915447              2.7                   120             45.0
# 22:30:44.333 INFO  ProgressMeter -       chr13:32930751              3.0                   180             60.4
# 22:30:56.696 INFO  ProgressMeter -       chr13:32938121              3.2                   210             66.0
# 22:31:13.281 INFO  ProgressMeter -       chr13:32956201              3.5                   280             80.9
# 22:31:26.665 INFO  ProgressMeter -       chr13:32972390              3.7                   340             92.3
# 22:32:07.235 INFO  ProgressMeter -       chr17:41197599              4.4                   350             80.3
# 22:32:20.088 INFO  ProgressMeter -       chr17:41223958              4.6                   460            100.6
# 22:32:43.066 INFO  ProgressMeter -       chr17:41244772              5.0                   550            111.0
# 22:33:23.294 INFO  ProgressMeter -       chr17:41246739              5.6                   560             99.5
# 22:33:23.702 INFO  HaplotypeCaller - 1081 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1081 total reads filtered out of 18790 reads processed
# 22:33:23.702 INFO  ProgressMeter -       chr17:41276012              5.6                   676            120.0
# 22:33:23.702 INFO  ProgressMeter - Traversal complete. Processed 676 total regions in 5.6 minutes.
# 22:33:23.748 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.06637383000000001
# 22:33:23.749 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 288.71543856100004
# 22:33:23.749 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 33.33 sec
# 22:33:23.750 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 10:33:23 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 5.66 minutes.
# Runtime.totalMemory()=587202560
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID  REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .   GT   G  272.6      .
# 1  chr13  32900363  .   CT   C  371.6      .
# 2  chr13  32903565  .   AT   A  148.6      .
# 3  chr13  32903635  .  TAA   T   49.6      .
# 4  chr13  32905046  .   AT   A  181.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.937;DP=27;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=0.137;DP=41;Ex...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=0.424;DP=13;Ex...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.362;DP=12;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.677;DP=26;E...  GT:AD:DP:GQ:PL
#
#                     23_R_119
# 0  0/1:17,10:27:99:280,0,489
# 1  0/1:22,18:40:99:379,0,556
# 2    0/1:7,6:13:99:156,0,186
# 3     0/1:9,2:11:57:57,0,372
# 4   0/1:16,8:24:99:189,0,444
