# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B197_Seq137.bam"
targeted_vcf = f"{data_root}/B197_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B197_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B197_Seq137.bam -O ../../data/B197_Seq137.vcf -L ../../data/location.bed
# 23:13:18.643 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 23:13:18.878 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:13:18.882 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 23:13:18.883 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 23:13:18.883 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 23:13:18.883 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 23:13:18.883 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 11:13:18 PM EEST
# 23:13:18.883 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:13:18.884 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:13:18.884 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 23:13:18.885 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 23:13:18.885 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 23:13:18.885 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 23:13:18.886 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 23:13:18.886 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 23:13:18.886 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 23:13:18.886 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 23:13:18.887 INFO  HaplotypeCaller - Inflater: IntelInflater
# 23:13:18.887 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 23:13:18.887 INFO  HaplotypeCaller - Requester pays: disabled
# 23:13:18.887 INFO  HaplotypeCaller - Initializing engine
# 23:13:19.183 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 23:13:19.197 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 23:13:19.204 INFO  HaplotypeCaller - Done initializing engine
# 23:13:19.221 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 23:13:19.236 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 23:13:19.307 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 23:13:19.307 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 23:13:19.307 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 23:13:19.437 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 23:13:19.438 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 23:13:19.438 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 23:13:19.471 INFO  ProgressMeter - Starting traversal
# 23:13:19.472 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 23:13:24.750 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32899399 and possibly subsequent; at least 10 samples must have called genotypes
# 23:13:29.725 INFO  ProgressMeter -       chr13:32902341              0.2                    50            292.6
# 23:13:45.433 INFO  ProgressMeter -       chr13:32907068              0.4                    70            161.8
# 23:14:04.454 INFO  ProgressMeter -       chr13:32911599              0.7                    90            120.0
# 23:14:20.780 INFO  ProgressMeter -       chr13:32912900              1.0                   100             97.9
# 23:14:46.659 INFO  ProgressMeter -       chr13:32914532              1.5                   110             75.7
# 23:15:03.431 INFO  ProgressMeter -       chr13:32930830              1.7                   170             98.1
# 23:15:16.942 INFO  ProgressMeter -       chr13:32938121              2.0                   200            102.2
# 23:15:27.525 INFO  ProgressMeter -       chr13:32970381              2.1                   320            149.9
# 23:15:47.416 INFO  ProgressMeter -       chr17:41197155              2.5                   340            137.9
# 23:15:59.919 INFO  ProgressMeter -       chr17:41244071              2.7                   540            201.9
# 23:16:16.985 INFO  ProgressMeter -       chr17:41245640              3.0                   550            185.9
# 23:16:27.589 INFO  ProgressMeter -       chr17:41247596              3.1                   560            178.6
# 23:16:28.599 INFO  HaplotypeCaller - 1137 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1137 total reads filtered out of 28845 reads processed
# 23:16:28.600 INFO  ProgressMeter -       chr17:41275431              3.2                   669            212.2
# 23:16:28.600 INFO  ProgressMeter - Traversal complete. Processed 669 total regions in 3.2 minutes.
# 23:16:28.625 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.045938716000000004
# 23:16:28.625 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 160.030172673
# 23:16:28.625 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 20.45 sec
# 23:16:28.626 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:16:28 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 3.17 minutes.
# Runtime.totalMemory()=603979776
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT   QUAL FILTER  \
# 0  chr13  32899399  .  AT   A   70.6      .
# 1  chr13  32900363  .  CT   C  406.6      .
# 2  chr13  32903565  .  AT   A  151.6      .
# 3  chr13  32903635  .  TA   T  434.6      .
# 4  chr13  32905046  .  AT   A  995.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.276;DP=83;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.188;DP=74;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=0.088;DP=57;Ex...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.216;DP=63;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.416;DP=67;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0   0/1:73,10:83:78:78,0,2051
# 1  0/1:51,23:74:99:414,0,1329
# 2   0/1:48,9:57:99:159,0,1377
# 3  0/1:39,23:62:99:442,0,1214
# 4  0/1:29,35:64:99:1003,0,740
