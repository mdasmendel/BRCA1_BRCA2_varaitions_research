# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B186_Seq137.bam"
targeted_vcf = f"{data_root}/B186_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B186_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B186_Seq137.bam -O ../../data/B186_Seq137.vcf -L ../../data/location.bed
# 22:57:01.272 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 22:57:01.553 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:57:01.559 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 22:57:01.560 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 22:57:01.560 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 22:57:01.560 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 22:57:01.560 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 10:57:01 PM EEST
# 22:57:01.560 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:57:01.561 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:57:01.562 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 22:57:01.562 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 22:57:01.562 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 22:57:01.562 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 22:57:01.563 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 22:57:01.563 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 22:57:01.564 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 22:57:01.564 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 22:57:01.565 INFO  HaplotypeCaller - Inflater: IntelInflater
# 22:57:01.565 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 22:57:01.565 INFO  HaplotypeCaller - Requester pays: disabled
# 22:57:01.567 INFO  HaplotypeCaller - Initializing engine
# 22:57:02.043 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 22:57:02.063 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 22:57:02.075 INFO  HaplotypeCaller - Done initializing engine
# 22:57:02.093 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 22:57:02.117 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 22:57:02.191 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 22:57:02.191 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 22:57:02.192 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 22:57:02.369 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 22:57:02.370 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 22:57:02.370 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 22:57:02.423 INFO  ProgressMeter - Starting traversal
# 22:57:02.423 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 22:57:05.228 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 22:57:17.068 INFO  ProgressMeter -       chr13:32900231              0.2                    40            163.9
# 22:57:41.328 INFO  ProgressMeter -       chr13:32906812              0.6                    70            108.0
# 22:57:57.059 INFO  ProgressMeter -       chr13:32909518              0.9                    80             87.9
# 22:58:29.046 INFO  ProgressMeter -       chr13:32911500              1.4                    90             62.3
# 22:59:04.308 INFO  ProgressMeter -       chr13:32912890              2.0                   100             49.2
# 23:00:04.322 INFO  ProgressMeter -       chr13:32914371              3.0                   110             36.3
# 23:00:23.059 INFO  ProgressMeter -       chr13:32916947              3.3                   120             35.9
# 23:00:37.315 INFO  ProgressMeter -       chr13:32930446              3.6                   170             47.5
# 23:00:47.548 INFO  ProgressMeter -       chr13:32932161              3.8                   180             48.0
# 23:01:03.620 INFO  ProgressMeter -       chr13:32937594              4.0                   200             49.8
# 23:01:15.242 INFO  ProgressMeter -       chr13:32953550              4.2                   260             61.7
# 23:01:27.053 INFO  ProgressMeter -       chr13:32969781              4.4                   320             72.6
# 23:02:00.368 INFO  ProgressMeter -       chr17:41197065              5.0                   340             68.5
# 23:02:11.935 INFO  ProgressMeter -       chr17:41223357              5.2                   450             87.2
# 23:02:35.274 INFO  ProgressMeter -       chr17:41244757              5.5                   540             97.3
# 23:03:22.517 INFO  ProgressMeter -       chr17:41246185              6.3                   550             86.8
# 23:03:38.682 INFO  ProgressMeter -       chr17:41248040              6.6                   560             84.8
# 23:03:42.701 INFO  HaplotypeCaller - 1703 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1703 total reads filtered out of 37443 reads processed
# 23:03:42.701 INFO  ProgressMeter -       chr17:41275937              6.7                   667            100.0
# 23:03:42.701 INFO  ProgressMeter - Traversal complete. Processed 667 total regions in 6.7 minutes.
# 23:03:42.737 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.07421554000000001
# 23:03:42.737 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 350.794552076
# 23:03:42.737 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 33.29 sec
# 23:03:42.738 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:03:42 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 6.69 minutes.
# Runtime.totalMemory()=486539264
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .  GT   G  459.6      .
# 1  chr13  32900363  .  CT   C  262.6      .
# 2  chr13  32900440  .  AT   A   81.6      .
# 3  chr13  32903565  .  AT   A  115.6      .
# 4  chr13  32903635  .  TA   T  504.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.059;DP=61;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.050;DP=77;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.469;DP=91;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.188;DP=57;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-4.726;DP=60;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:42,19:61:99:467,0,1337
# 1  0/1:57,19:76:99:270,0,1481
# 2   0/1:79,11:90:89:89,0,2276
# 3   0/1:48,9:57:99:123,0,1313
# 4  0/1:34,26:60:99:512,0,1035
