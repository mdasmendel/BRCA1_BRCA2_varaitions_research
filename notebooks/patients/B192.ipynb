# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B192_Seq137.bam"
targeted_vcf = f"{data_root}/B192_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B192_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B192_Seq137.bam -O ../../data/B192_Seq137.vcf -L ../../data/location.bed
# 23:08:27.423 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 23:08:27.768 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:08:27.771 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 23:08:27.771 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 23:08:27.771 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 23:08:27.771 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 23:08:27.771 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 11:08:27 PM EEST
# 23:08:27.771 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:08:27.772 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:08:27.772 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 23:08:27.772 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 23:08:27.772 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 23:08:27.773 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 23:08:27.773 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 23:08:27.774 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 23:08:27.774 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 23:08:27.774 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 23:08:27.775 INFO  HaplotypeCaller - Inflater: IntelInflater
# 23:08:27.775 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 23:08:27.775 INFO  HaplotypeCaller - Requester pays: disabled
# 23:08:27.776 INFO  HaplotypeCaller - Initializing engine
# 23:08:28.080 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 23:08:28.093 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 23:08:28.100 INFO  HaplotypeCaller - Done initializing engine
# 23:08:28.116 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 23:08:28.130 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 23:08:28.300 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 23:08:28.301 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 23:08:28.301 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 23:08:28.485 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 23:08:28.486 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 23:08:28.486 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 23:08:28.514 INFO  ProgressMeter - Starting traversal
# 23:08:28.515 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 23:08:30.024 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 23:08:39.978 INFO  ProgressMeter -       chr13:32902341              0.2                    50            261.7
# 23:08:57.412 INFO  ProgressMeter -       chr13:32906808              0.5                    70            145.3
# 23:09:28.380 INFO  ProgressMeter -       chr13:32911500              1.0                    90             90.2
# 23:09:53.432 INFO  ProgressMeter -       chr13:32912890              1.4                   100             70.7
# 23:10:22.777 INFO  ProgressMeter -       chr13:32914198              1.9                   110             57.8
# 23:10:40.965 INFO  ProgressMeter -       chr13:32916047              2.2                   120             54.4
# 23:10:50.971 INFO  ProgressMeter -       chr13:32929265              2.4                   170             71.6
# 23:11:11.020 INFO  ProgressMeter -       chr13:32939324              2.7                   210             77.5
# 23:11:26.571 INFO  ProgressMeter -       chr13:32954053              3.0                   270             91.0
# 23:11:45.645 INFO  ProgressMeter -       chr13:32972554              3.3                   340            103.5
# 23:12:02.751 INFO  ProgressMeter -       chr17:41197813              3.6                   350             98.0
# 23:12:16.320 INFO  ProgressMeter -       chr17:41227238              3.8                   480            126.4
# 23:12:36.354 INFO  ProgressMeter -       chr17:41244167              4.1                   550            133.2
# 23:13:19.702 INFO  ProgressMeter -       chr17:41245921              4.9                   560            115.4
# 23:13:40.275 INFO  ProgressMeter -       chr17:41247770              5.2                   570            109.7
# 23:13:44.274 INFO  HaplotypeCaller - 1970 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1970 total reads filtered out of 45036 reads processed
# 23:13:44.275 INFO  ProgressMeter -       chr17:41275431              5.3                   679            129.0
# 23:13:44.275 INFO  ProgressMeter - Traversal complete. Processed 679 total regions in 5.3 minutes.
# 23:13:44.309 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.062464602
# 23:13:44.309 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 277.283753821
# 23:13:44.310 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 26.41 sec
# 23:13:44.311 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:13:44 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 5.28 minutes.
# Runtime.totalMemory()=528482304
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT    QUAL FILTER  \
# 0  chr13  32893180  .  GT   G   563.6      .
# 1  chr13  32900363  .  CT   C   221.6      .
# 2  chr13  32903635  .  TA   T   409.6      .
# 3  chr13  32905046  .  AT   A  1143.6      .
# 4  chr13  32905066  .   G  GA    40.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.566;DP=86;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.961;DP=83;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-5.240;DP=82;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.810;DP=79;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-4.012;DP=75;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:63,23:86:99:571,0,2023
# 1  0/1:67,16:83:99:229,0,1803
# 2  0/1:58,24:82:99:417,0,1821
# 3  0/1:36,39:75:99:1151,0,965
# 4    0/1:68,7:75:48:48,0,2725
