# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B182_Seq136.bam"
targeted_vcf = f"{data_root}/B182_Seq136.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B182_Seq136.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B182_Seq136.bam -O ../../data/B182_Seq136.vcf -L ../../data/location.bed
# 22:53:19.455 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 22:53:19.819 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:53:19.824 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 22:53:19.825 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 22:53:19.825 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 22:53:19.825 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 22:53:19.825 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 10:53:19 PM EEST
# 22:53:19.825 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:53:19.825 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:53:19.827 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 22:53:19.828 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 22:53:19.828 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 22:53:19.828 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 22:53:19.828 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 22:53:19.828 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 22:53:19.829 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 22:53:19.829 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 22:53:19.830 INFO  HaplotypeCaller - Inflater: IntelInflater
# 22:53:19.830 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 22:53:19.831 INFO  HaplotypeCaller - Requester pays: disabled
# 22:53:19.832 INFO  HaplotypeCaller - Initializing engine
# 22:53:20.215 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 22:53:20.224 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 22:53:20.236 INFO  HaplotypeCaller - Done initializing engine
# 22:53:20.251 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 22:53:20.271 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 22:53:20.438 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 22:53:20.439 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 22:53:20.439 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 22:53:20.634 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 22:53:20.635 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 22:53:20.635 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 22:53:20.685 INFO  ProgressMeter - Starting traversal
# 22:53:20.686 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 22:53:22.922 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 22:53:31.323 INFO  ProgressMeter -       chr13:32902341              0.2                    50            282.1
# 22:53:49.814 INFO  ProgressMeter -       chr13:32906772              0.5                    70            144.2
# 22:54:05.092 INFO  ProgressMeter -       chr13:32908918              0.7                    80            108.1
# 22:54:24.356 INFO  ProgressMeter -       chr13:32911126              1.1                    90             84.8
# 22:55:06.420 INFO  ProgressMeter -       chr13:32912888              1.8                   100             56.7
# 22:55:39.508 INFO  ProgressMeter -       chr13:32913745              2.3                   110             47.5
# 22:56:11.863 INFO  ProgressMeter -       chr13:32915747              2.9                   120             42.1
# 22:56:26.568 INFO  ProgressMeter -       chr13:32929269              3.1                   170             54.9
# 22:56:38.833 INFO  ProgressMeter -       chr13:32933661              3.3                   190             57.5
# 22:56:57.478 INFO  ProgressMeter -       chr13:32939021              3.6                   210             58.1
# 22:57:18.387 INFO  ProgressMeter -       chr13:32954231              4.0                   270             68.2
# 22:57:31.661 INFO  ProgressMeter -       chr13:32971017              4.2                   330             78.9
# 22:58:02.199 INFO  ProgressMeter -       chr13:32972550              4.7                   340             72.5
# 22:58:24.251 INFO  ProgressMeter -       chr17:41197813              5.1                   350             69.2
# 22:58:34.427 INFO  ProgressMeter -       chr17:41215947              5.2                   430             82.2
# 22:58:47.900 INFO  ProgressMeter -       chr17:41236784              5.5                   510             93.5
# 22:59:09.516 INFO  ProgressMeter -       chr17:41244167              5.8                   540             92.9
# 22:59:45.937 INFO  ProgressMeter -       chr17:41245640              6.4                   550             85.7
# 23:00:16.225 INFO  ProgressMeter -       chr17:41248040              6.9                   560             80.9
# 23:00:20.154 INFO  HaplotypeCaller - 2418 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 2418 total reads filtered out of 55257 reads processed
# 23:00:20.155 INFO  ProgressMeter -       chr17:41276039              7.0                   665             95.1
# 23:00:20.155 INFO  ProgressMeter - Traversal complete. Processed 665 total regions in 7.0 minutes.
# 23:00:20.194 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.081917497
# 23:00:20.194 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 367.396281938
# 23:00:20.194 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 36.26 sec
# 23:00:20.195 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:00:20 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 7.01 minutes.
# Runtime.totalMemory()=478150656
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .  GT   G  931.6      .
# 1  chr13  32900363  .  CT   C  688.6      .
# 2  chr13  32900440  .  AT   A  177.6      .
# 3  chr13  32903565  .  AT   A  215.6      .
# 4  chr13  32905046  .  AT   A  745.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-4.871;DP=82;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.742;DP=79;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.855;DP=97;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.399;DP=45;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-4.055;DP=75;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:49,33:82:99:939,0,1537
# 1  0/1:46,31:77:99:696,0,1136
# 2  0/1:83,13:96:99:185,0,2403
# 3   0/1:34,11:45:99:223,0,943
# 4  0/1:39,26:65:99:753,0,1061
