# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B178_Seq136.bam"
targeted_vcf = f"{data_root}/B178_Seq136.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B178_Seq136.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B178_Seq136.bam -O ../../data/B178_Seq136.vcf -L ../../data/location.bed
# 22:27:50.209 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 22:27:50.432 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:50.438 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 22:27:50.438 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 22:27:50.438 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 22:27:50.438 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 22:27:50.438 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 10:27:50 PM EEST
# 22:27:50.438 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:50.439 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:27:50.440 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 22:27:50.440 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 22:27:50.441 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 22:27:50.441 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 22:27:50.441 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 22:27:50.442 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 22:27:50.442 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 22:27:50.442 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 22:27:50.442 INFO  HaplotypeCaller - Inflater: IntelInflater
# 22:27:50.442 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 22:27:50.442 INFO  HaplotypeCaller - Requester pays: disabled
# 22:27:50.443 INFO  HaplotypeCaller - Initializing engine
# 22:27:51.054 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 22:27:51.068 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 22:27:51.078 INFO  HaplotypeCaller - Done initializing engine
# 22:27:51.102 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 22:27:51.130 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 22:27:51.252 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 22:27:51.253 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 22:27:51.254 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 22:27:51.484 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 22:27:51.485 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 22:27:51.485 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 22:27:51.561 INFO  ProgressMeter - Starting traversal
# 22:27:51.562 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 22:27:53.433 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 22:28:06.151 INFO  ProgressMeter -       chr13:32900679              0.2                    40            164.5
# 22:28:46.584 INFO  ProgressMeter -       chr13:32907307              0.9                    70             76.3
# 22:29:47.004 INFO  ProgressMeter -       chr13:32912043              1.9                    90             46.8
# 22:30:16.971 INFO  ProgressMeter -       chr13:32912988              2.4                   100             41.3
# 22:31:30.014 INFO  ProgressMeter -       chr13:32915199              3.6                   110             30.2
# 22:31:51.146 INFO  ProgressMeter -       chr13:32930837              4.0                   170             42.6
# 22:32:02.117 INFO  ProgressMeter -       chr13:32932761              4.2                   180             43.1
# 22:32:32.394 INFO  ProgressMeter -       chr13:32937598              4.7                   200             42.7
# 22:32:44.333 INFO  ProgressMeter -       chr13:32953479              4.9                   260             53.3
# 22:33:01.038 INFO  ProgressMeter -       chr13:32970081              5.2                   320             62.0
# 22:33:46.168 INFO  ProgressMeter -       chr17:41197249              5.9                   340             57.5
# 22:33:58.921 INFO  ProgressMeter -       chr17:41223957              6.1                   450             73.5
# 22:34:19.104 INFO  ProgressMeter -       chr17:41244167              6.5                   530             82.1
# 22:34:59.133 INFO  ProgressMeter -       chr17:41245923              7.1                   540             75.8
# 22:35:29.505 INFO  ProgressMeter -       chr17:41247596              7.6                   550             72.1
# 22:35:34.103 INFO  HaplotypeCaller - 1637 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1637 total reads filtered out of 34388 reads processed
# 22:35:34.103 INFO  ProgressMeter -       chr17:41277197              7.7                   661             85.7
# 22:35:34.103 INFO  ProgressMeter - Traversal complete. Processed 661 total regions in 7.7 minutes.
# 22:35:34.136 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.085527131
# 22:35:34.137 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 406.73876884000003
# 22:35:34.137 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 38.15 sec
# 22:35:34.138 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 10:35:34 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 7.73 minutes.
# Runtime.totalMemory()=591396864
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID  REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .   GT   G  226.6      .
# 1  chr13  32900363  .   CT   C  340.6      .
# 2  chr13  32903565  .   AT   A  192.6      .
# 3  chr13  32903635  .  TAA   T  546.6      .
# 4  chr13  32905046  .   AT   A  488.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.957;DP=60;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.456;DP=82;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.595;DP=42;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.942;DP=47;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.984;DP=67;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0   0/1:24,36:60:99:234,0,669
# 1  0/1:50,28:78:99:348,0,1193
# 2   0/1:32,10:42:99:200,0,859
# 3  0/1:25,15:40:99:554,0,1006
# 4  0/1:36,20:56:99:496,0,1007
