# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B198_Seq137.bam"
targeted_vcf = f"{data_root}/B198_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B198_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B198_Seq137.bam -O ../../data/B198_Seq137.vcf -L ../../data/location.bed
# 23:09:57.865 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 23:09:58.023 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:09:58.027 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 23:09:58.027 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 23:09:58.027 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 23:09:58.028 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 23:09:58.028 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 11:09:57 PM EEST
# 23:09:58.028 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:09:58.028 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:09:58.029 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 23:09:58.029 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 23:09:58.029 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 23:09:58.029 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 23:09:58.029 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 23:09:58.030 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 23:09:58.030 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 23:09:58.030 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 23:09:58.030 INFO  HaplotypeCaller - Inflater: IntelInflater
# 23:09:58.030 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 23:09:58.030 INFO  HaplotypeCaller - Requester pays: disabled
# 23:09:58.031 INFO  HaplotypeCaller - Initializing engine
# 23:09:58.387 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 23:09:58.394 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 23:09:58.403 INFO  HaplotypeCaller - Done initializing engine
# 23:09:58.416 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 23:09:58.430 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 23:09:58.530 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 23:09:58.531 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 23:09:58.532 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 23:09:58.655 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 23:09:58.655 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 23:09:58.655 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 23:09:58.696 INFO  ProgressMeter - Starting traversal
# 23:09:58.696 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 23:09:59.811 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 23:10:18.262 INFO  ProgressMeter -       chr13:32906712              0.3                    70            214.7
# 23:10:30.799 INFO  ProgressMeter -       chr13:32908918              0.5                    80            149.5
# 23:10:49.335 INFO  ProgressMeter -       chr13:32911222              0.8                    90            106.6
# 23:11:10.510 INFO  ProgressMeter -       chr13:32912889              1.2                   100             83.5
# 23:11:30.690 INFO  ProgressMeter -       chr13:32914198              1.5                   110             71.7
# 23:11:48.445 INFO  ProgressMeter -       chr13:32916647              1.8                   120             65.6
# 23:11:58.655 INFO  ProgressMeter -       chr13:32930146              2.0                   170             85.0
# 23:12:12.676 INFO  ProgressMeter -       chr13:32939921              2.2                   210             94.0
# 23:12:23.541 INFO  ProgressMeter -       chr13:32969181              2.4                   320            132.6
# 23:12:36.656 INFO  ProgressMeter -       chr13:32972545              2.6                   340            129.1
# 23:12:51.142 INFO  ProgressMeter -       chr17:41197813              2.9                   350            121.8
# 23:13:13.824 INFO  ProgressMeter -       chr17:41244757              3.3                   550            169.1
# 23:13:38.499 INFO  ProgressMeter -       chr17:41246187              3.7                   560            152.9
# 23:13:49.547 INFO  ProgressMeter -       chr17:41250676              3.8                   580            150.7
# 23:13:50.921 INFO  HaplotypeCaller - 1187 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1187 total reads filtered out of 27938 reads processed
# 23:13:50.921 INFO  ProgressMeter -       chr17:41277497              3.9                   680            175.7
# 23:13:50.921 INFO  ProgressMeter - Traversal complete. Processed 680 total regions in 3.9 minutes.
# 23:13:50.954 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.051267496
# 23:13:50.955 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 197.75489975300002
# 23:13:50.955 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 24.09 sec
# 23:13:50.956 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:13:50 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 3.89 minutes.
# Runtime.totalMemory()=587202560
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID  REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .   GT   G  495.6      .
# 1  chr13  32899399  .   AT   A   42.6      .
# 2  chr13  32900363  .   CT   C  452.6      .
# 3  chr13  32900440  .   AT   A  255.6      .
# 4  chr13  32903635  .  TAA   T  115.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.493;DP=65;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.245;DP=71;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.550;DP=77;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-4.472;DP=82;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.541;DP=37;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:45,20:65:99:503,0,1436
# 1    0/1:63,8:71:50:50,0,1675
# 2  0/1:53,23:76:99:460,0,1376
# 3  0/1:67,15:82:99:263,0,1920
# 4   0/1:28,5:33:99:123,0,1163
