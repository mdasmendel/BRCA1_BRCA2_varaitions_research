# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/B187_Seq137.bam"
targeted_vcf = f"{data_root}/B187_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/B187_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/B187_Seq137.bam -O ../../data/B187_Seq137.vcf -L ../../data/location.bed
# 22:57:13.910 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 22:57:14.086 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:57:14.090 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 22:57:14.090 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 22:57:14.091 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 22:57:14.091 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 22:57:14.091 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 10:57:13 PM EEST
# 22:57:14.091 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:57:14.091 INFO  HaplotypeCaller - ------------------------------------------------------------
# 22:57:14.092 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 22:57:14.092 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 22:57:14.092 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 22:57:14.093 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 22:57:14.093 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 22:57:14.093 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 22:57:14.093 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 22:57:14.094 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 22:57:14.094 INFO  HaplotypeCaller - Inflater: IntelInflater
# 22:57:14.094 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 22:57:14.094 INFO  HaplotypeCaller - Requester pays: disabled
# 22:57:14.095 INFO  HaplotypeCaller - Initializing engine
# 22:57:14.474 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 22:57:14.493 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 22:57:14.501 INFO  HaplotypeCaller - Done initializing engine
# 22:57:14.533 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 22:57:14.551 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 22:57:14.625 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 22:57:14.625 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 22:57:14.626 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 22:57:14.814 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 22:57:14.815 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 22:57:14.815 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 22:57:14.863 INFO  ProgressMeter - Starting traversal
# 22:57:14.863 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 22:57:21.422 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 22:57:29.035 INFO  ProgressMeter -       chr13:32900405              0.2                    40            169.3
# 22:57:53.500 INFO  ProgressMeter -       chr13:32906807              0.6                    70            108.7
# 22:58:03.905 INFO  ProgressMeter -       chr13:32909218              0.8                    80             97.9
# 22:58:58.635 INFO  ProgressMeter -       chr13:32911500              1.7                    90             52.0
# 22:59:43.551 INFO  ProgressMeter -       chr13:32912889              2.5                   100             40.4
# 23:00:35.929 INFO  ProgressMeter -       chr13:32914198              3.4                   110             32.8
# 23:01:08.261 INFO  ProgressMeter -       chr13:32916647              3.9                   120             30.8
# 23:01:24.519 INFO  ProgressMeter -       chr13:32930470              4.2                   170             40.9
# 23:01:54.294 INFO  ProgressMeter -       chr13:32937594              4.7                   200             42.9
# 23:02:05.559 INFO  ProgressMeter -       chr13:32955601              4.8                   270             55.7
# 23:02:16.305 INFO  ProgressMeter -       chr13:32970081              5.0                   320             63.7
# 23:02:53.195 INFO  ProgressMeter -       chr17:41196566              5.6                   340             60.3
# 23:03:03.233 INFO  ProgressMeter -       chr17:41209552              5.8                   400             68.9
# 23:03:14.666 INFO  ProgressMeter -       chr17:41228722              6.0                   480             80.0
# 23:03:30.242 INFO  ProgressMeter -       chr17:41244071              6.3                   540             86.3
# 23:04:06.313 INFO  ProgressMeter -       chr17:41245639              6.9                   550             80.2
# 23:04:33.006 INFO  ProgressMeter -       chr17:41247596              7.3                   560             76.7
# 23:04:39.567 INFO  HaplotypeCaller - 1931 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1931 total reads filtered out of 47616 reads processed
# 23:04:39.567 INFO  ProgressMeter -       chr17:41275436              7.4                   669             90.3
# 23:04:39.567 INFO  ProgressMeter - Traversal complete. Processed 669 total regions in 7.4 minutes.
# 23:04:39.601 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.08050657400000001
# 23:04:39.603 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 393.31461481800005
# 23:04:39.603 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 34.40 sec
# 23:04:39.604 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:04:39 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 7.43 minutes.
# Runtime.totalMemory()=536870912
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .  GT   G   48.6      .
# 1  chr13  32900363  .  CT   C  259.6      .
# 2  chr13  32900440  .  AT   A  135.6      .
# 3  chr13  32903565  .  AT   A   92.6      .
# 4  chr13  32905046  .  AT   A  792.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.463;DP=78;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.180;DP=76;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.315;DP=84;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.701;DP=54;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.103;DP=72;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0   0/1:56,22:78:56:56,0,1784
# 1  0/1:57,18:75:99:267,0,1486
# 2  0/1:71,12:83:99:143,0,2026
# 3   0/1:46,8:54:99:100,0,1228
# 4  0/1:41,29:70:99:800,0,1112
