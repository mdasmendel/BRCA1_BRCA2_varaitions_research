# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/R125_Seq137.bam"
targeted_vcf = f"{data_root}/R125_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/R125_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/R125_Seq137.bam -O ../../data/R125_Seq137.vcf -L ../../data/location.bed
# 23:19:22.001 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 23:19:22.178 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:22.183 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 23:19:22.183 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 23:19:22.183 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 23:19:22.183 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 23:19:22.183 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 11:19:21 PM EEST
# 23:19:22.184 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:22.184 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:22.185 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 23:19:22.185 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 23:19:22.185 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 23:19:22.186 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 23:19:22.186 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 23:19:22.186 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 23:19:22.186 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 23:19:22.187 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 23:19:22.187 INFO  HaplotypeCaller - Inflater: IntelInflater
# 23:19:22.187 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 23:19:22.187 INFO  HaplotypeCaller - Requester pays: disabled
# 23:19:22.188 INFO  HaplotypeCaller - Initializing engine
# 23:19:22.662 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 23:19:22.693 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 23:19:22.701 INFO  HaplotypeCaller - Done initializing engine
# 23:19:22.754 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 23:19:22.768 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 23:19:22.832 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 23:19:22.833 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 23:19:22.834 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 23:19:23.042 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 23:19:23.042 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 23:19:23.042 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 23:19:23.085 INFO  ProgressMeter - Starting traversal
# 23:19:23.085 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 23:19:23.928 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 23:19:41.438 INFO  ProgressMeter -       chr13:32908018              0.3                    80            261.5
# 23:20:09.658 INFO  ProgressMeter -       chr13:32912426              0.8                   100            128.8
# 23:20:44.858 INFO  ProgressMeter -       chr13:32915195              1.4                   120             88.0
# 23:20:55.288 INFO  ProgressMeter -       chr13:32936932              1.5                   210            136.7
# 23:21:06.263 INFO  ProgressMeter -       chr13:32954235              1.7                   280            162.8
# 23:21:34.708 INFO  ProgressMeter -       chr17:41197599              2.2                   360            164.1
# 23:21:52.989 INFO  ProgressMeter -       chr17:41245640              2.5                   560            224.1
# 23:21:59.380 INFO  HaplotypeCaller - 612 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 612 total reads filtered out of 13041 reads processed
# 23:21:59.380 INFO  ProgressMeter -       chr17:41276897              2.6                   682            261.8
# 23:21:59.380 INFO  ProgressMeter - Traversal complete. Processed 682 total regions in 2.6 minutes.
# 23:21:59.413 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.05315882500000001
# 23:21:59.414 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 121.656544029
# 23:21:59.414 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 24.24 sec
# 23:21:59.415 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:21:59 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 2.62 minutes.
# Runtime.totalMemory()=402653184
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT   QUAL FILTER  \
# 0  chr13  32893180  .  GT   G  111.6      .
# 1  chr13  32900363  .  CT   C  376.6      .
# 2  chr13  32903635  .  TA   T  197.6      .
# 3  chr13  32905046  .  AT   A  498.6      .
# 4  chr13  32905097  .  GA   G  169.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.977;DP=20;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.019;DP=63;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-2.997;DP=23;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.882;DP=38;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-0.591;DP=82;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0    0/1:15,5:20:99:119,0,467
# 1  0/1:43,20:63:99:384,0,1127
# 2   0/1:13,10:23:99:205,0,396
# 3   0/1:18,18:36:99:506,0,486
# 4    0/1:30,9:39:99:177,0,853
