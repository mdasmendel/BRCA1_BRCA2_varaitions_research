# %% [markdown]
# Import and declare variables

# %%
import subprocess
import os

data_root = "../../data"

reference_genome = f"{data_root}/hg19.fasta"
reference_genome_dict = f"{data_root}/hg19.dict"
reference_genome_fai = f"{data_root}/hg19.fai"
input_bam = f"{data_root}/DataBreastCancerPatients/R134_Seq137.bam"
targeted_vcf = f"{data_root}/R134_Seq137.vcf"

if not os.path.isfile(reference_genome):
    raise FileNotFoundError("reference genome is missing, add it please")
if not os.path.isfile(input_bam):
    raise FileNotFoundError("patient input bam file is missing, add it please")

# %% [raw]
# Indexing the reference genome

# %%
if not os.path.isfile(reference_genome_fai):
    subprocess.run([f"samtools faidx {reference_genome}"], shell=True)

# %% [markdown]
# Create dict file required for VCF file generation

# %%
if not os.path.isfile(reference_genome_dict):
    subprocess.call([f"gatk CreateSequenceDictionary -R {reference_genome} -O {reference_genome_dict}"], shell=True)

# %% [markdown]
# Indexing the input bam file

# %%
subprocess.run([f"samtools index {input_bam}"], shell=True)
# Out:
# CompletedProcess(args=['samtools index ../../data/DataBreastCancerPatients/R134_Seq137.bam'], returncode=0)

# %% [raw]
# variant calling and obtaining VCF file

# %%
subprocess.call([f"gatk HaplotypeCaller -R {reference_genome} -I {input_bam} -O {targeted_vcf} -L ../../data/location.bed"], shell=True)
# Out:
# Using GATK jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar HaplotypeCaller -R ../../data/hg19.fasta -I ../../data/DataBreastCancerPatients/R134_Seq137.bam -O ../../data/R134_Seq137.vcf -L ../../data/location.bed
# 23:19:38.980 INFO  NativeLibraryLoader - Loading libgkl_compression.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.dylib
# 23:19:39.151 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:39.157 INFO  HaplotypeCaller - The Genome Analysis Toolkit (GATK) v4.4.0.0
# 23:19:39.157 INFO  HaplotypeCaller - For support and documentation go to https://software.broadinstitute.org/gatk/
# 23:19:39.157 INFO  HaplotypeCaller - Executing as dascal@Mihais-MacBook-Pro.local on Mac OS X v12.4 x86_64
# 23:19:39.157 INFO  HaplotypeCaller - Java runtime: OpenJDK 64-Bit Server VM v17.0.3+7-LTS
# 23:19:39.159 INFO  HaplotypeCaller - Start Date/Time: July 1, 2023 at 11:19:38 PM EEST
# 23:19:39.159 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:39.159 INFO  HaplotypeCaller - ------------------------------------------------------------
# 23:19:39.161 INFO  HaplotypeCaller - HTSJDK Version: 3.0.5
# 23:19:39.161 INFO  HaplotypeCaller - Picard Version: 3.0.0
# 23:19:39.161 INFO  HaplotypeCaller - Built for Spark Version: 3.3.1
# 23:19:39.161 INFO  HaplotypeCaller - HTSJDK Defaults.COMPRESSION_LEVEL : 2
# 23:19:39.162 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_READ_FOR_SAMTOOLS : false
# 23:19:39.162 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_SAMTOOLS : true
# 23:19:39.162 INFO  HaplotypeCaller - HTSJDK Defaults.USE_ASYNC_IO_WRITE_FOR_TRIBBLE : false
# 23:19:39.162 INFO  HaplotypeCaller - Deflater: IntelDeflater
# 23:19:39.162 INFO  HaplotypeCaller - Inflater: IntelInflater
# 23:19:39.162 INFO  HaplotypeCaller - GCS max retries/reopens: 20
# 23:19:39.163 INFO  HaplotypeCaller - Requester pays: disabled
# 23:19:39.163 INFO  HaplotypeCaller - Initializing engine
# 23:19:39.601 INFO  FeatureManager - Using codec BEDCodec to read file file:///Users/dascal/PycharmProjects/scientificProject/notebooks/patients/../../data/location.bed
# 23:19:39.609 INFO  IntervalArgumentCollection - Processing 163497 bp from intervals
# 23:19:39.617 INFO  HaplotypeCaller - Done initializing engine
# 23:19:39.646 INFO  HaplotypeCallerEngine - Disabling physical phasing, which is supported only for reference-model confidence output
# 23:19:39.660 INFO  NativeLibraryLoader - Loading libgkl_utils.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_utils.dylib
# 23:19:39.730 WARN  NativeLibraryLoader - Unable to find native library: native/libgkl_pairhmm_omp.dylib
# 23:19:39.730 INFO  PairHMM - OpenMP multi-threaded AVX-accelerated native PairHMM implementation is not supported
# 23:19:39.731 INFO  NativeLibraryLoader - Loading libgkl_pairhmm.dylib from jar:file:/Users/dascal/opt/anaconda3/envs/mamarCancer/share/gatk4-4.4.0.0-0/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_pairhmm.dylib
# 23:19:39.909 INFO  IntelPairHmm - Flush-to-zero (FTZ) is enabled when running PairHMM
# 23:19:39.910 WARN  IntelPairHmm - Ignoring request for 4 threads; not using OpenMP implementation
# 23:19:39.910 INFO  PairHMM - Using the AVX-accelerated native PairHMM implementation
# 23:19:39.947 INFO  ProgressMeter - Starting traversal
# 23:19:39.947 INFO  ProgressMeter -        Current Locus  Elapsed Minutes     Regions Processed   Regions/Minute
# 23:19:41.130 WARN  InbreedingCoeff - InbreedingCoeff will not be calculated at position chr13:32893180 and possibly subsequent; at least 10 samples must have called genotypes
# 23:19:53.218 INFO  ProgressMeter -       chr13:32900289              0.2                    40            180.9
# 23:20:11.860 INFO  ProgressMeter -       chr13:32906515              0.5                    70            131.6
# 23:20:37.174 INFO  ProgressMeter -       chr13:32908618              1.0                    80             83.9
# 23:21:02.737 INFO  ProgressMeter -       chr13:32910903              1.4                    90             65.2
# 23:21:52.332 INFO  ProgressMeter -       chr13:32912434              2.2                   100             45.3
# 23:22:16.411 INFO  ProgressMeter -       chr13:32913270              2.6                   110             42.2
# 23:23:08.431 INFO  ProgressMeter -       chr13:32915200              3.5                   120             34.5
# 23:23:25.663 INFO  ProgressMeter -       chr13:32930613              3.8                   180             47.8
# 23:23:46.389 INFO  ProgressMeter -       chr13:32938121              4.1                   210             51.1
# 23:24:02.088 INFO  ProgressMeter -       chr13:32956201              4.4                   280             64.1
# 23:24:51.715 INFO  ProgressMeter -       chr17:41197063              5.2                   350             67.4
# 23:25:02.124 INFO  ProgressMeter -       chr17:41222849              5.4                   460             85.7
# 23:25:13.481 INFO  ProgressMeter -       chr17:41230527              5.6                   490             88.1
# 23:25:32.185 INFO  ProgressMeter -       chr17:41244757              5.9                   550             93.7
# 23:26:04.866 INFO  ProgressMeter -       chr17:41246285              6.4                   560             87.3
# 23:26:15.043 INFO  ProgressMeter -       chr17:41253807              6.6                   590             89.6
# 23:26:18.225 INFO  HaplotypeCaller - 1609 read(s) filtered by: MappingQualityReadFilter
# 0 read(s) filtered by: MappingQualityAvailableReadFilter
# 0 read(s) filtered by: MappedReadFilter
# 0 read(s) filtered by: NotSecondaryAlignmentReadFilter
# 0 read(s) filtered by: NotDuplicateReadFilter
# 0 read(s) filtered by: PassesVendorQualityCheckReadFilter
# 0 read(s) filtered by: NonZeroReferenceLengthAlignmentReadFilter
# 0 read(s) filtered by: GoodCigarReadFilter
# 0 read(s) filtered by: WellformedReadFilter
# 1609 total reads filtered out of 42128 reads processed
# 23:26:18.225 INFO  ProgressMeter -       chr17:41276035              6.6                   675            101.7
# 23:26:18.225 INFO  ProgressMeter - Traversal complete. Processed 675 total regions in 6.6 minutes.
# 23:26:18.263 INFO  VectorLoglessPairHMM - Time spent in setup for JNI call : 0.068593823
# 23:26:18.264 INFO  PairHMM - Total compute time in PairHMM computeLogLikelihoods() : 350.64680323500005
# 23:26:18.264 INFO  SmithWatermanAligner - Total compute time in java Smith-Waterman : 31.92 sec
# 23:26:18.265 INFO  HaplotypeCaller - Shutting down engine
# [July 1, 2023 at 11:26:18 PM EEST] org.broadinstitute.hellbender.tools.walkers.haplotypecaller.HaplotypeCaller done. Elapsed time: 6.66 minutes.
# Runtime.totalMemory()=595591168
# 0

# %% [markdown]
# Show chromosome spreading

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by chromosome and count the number of variants
# Define the column names
col_names = ['CHROM','POS','ID','REF','ALT','QUAL','FILTER','INFO','FORMAT','23_R_119']

# Load the VCF file
df = pd.read_csv(targeted_vcf, comment='#', sep='\t', names=col_names)

# View the first few rows
print(df.head())

variant_counts = df['CHROM'].value_counts()

# Create a bar plot of the variant counts
plt.bar(variant_counts.index, variant_counts.values)
plt.xlabel('Chromosome')
plt.ylabel('Number of Variants')
plt.title('Variant Distribution by Chromosome')
plt.show()

chromosomes = df['CHROM'].unique()

# For each chromosome
for chrom in chromosomes:
    # Filter the DataFrame for only rows corresponding to this chromosome
    df_chrom = df[df['CHROM'] == chrom]

    # Generate the plot for this chromosome
    plt.figure(figsize=(10, 5))
    plt.scatter(df_chrom['POS'], [1]*len(df_chrom), alpha=0.1)
    plt.yticks([])
    plt.title('Variants on Chromosome {}'.format(chrom))
    plt.xlabel('Position')
    plt.show()
# Out:
#    CHROM       POS ID REF ALT    QUAL FILTER  \
# 0  chr13  32893180  .  GT   G   409.6      .
# 1  chr13  32900363  .  CT   C   312.6      .
# 2  chr13  32903635  .  TA   T   830.6      .
# 3  chr13  32905046  .  AT   A  1034.6      .
# 4  chr13  32905061  .  GA   G    41.6      .
#
#                                                 INFO          FORMAT  \
# 0  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.727;DP=92;E...  GT:AD:DP:GQ:PL
# 1  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.191;DP=89;E...  GT:AD:DP:GQ:PL
# 2  AC=1;AF=0.500;AN=2;BaseQRankSum=-5.386;DP=68;E...  GT:AD:DP:GQ:PL
# 3  AC=1;AF=0.500;AN=2;BaseQRankSum=-3.248;DP=79;E...  GT:AD:DP:GQ:PL
# 4  AC=1;AF=0.500;AN=2;BaseQRankSum=-1.634;DP=77;E...  GT:AD:DP:GQ:PL
#
#                      23_R_119
# 0  0/1:71,21:92:99:417,0,2252
# 1  0/1:70,19:89:99:320,0,1859
# 2   0/1:31,37:68:99:838,0,903
# 3  0/1:35,41:76:99:1042,0,899
# 4    0/1:62,7:69:49:49,0,1840
